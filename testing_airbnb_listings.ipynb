# %%
from dotenv import load_dotenv
load_dotenv()  # loads your API key (under var "OPENAI_API_KEY")
import os
import eda_tool

# %%
eda = eda_tool.EDA('data/listings.csv')
# Out:
# /Users/nima/Documents/School/CMPT 419 - Nick/AutoEDA/venv/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/nima/Documents/School/CMPT 419 - Nick/AutoEDA/venv/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# ### Data Summary
# ...

# %%
eda.plot_scatter(x='number_of_reviews', y='price', hue='room_type', title='Scatter Plot of Number of Reviews vs Price')
# Out:
# ---
# ### LLM Analysis & Suggestion
# # Analysis
#
# The scatter plot titled "Scatter Plot of Number of Reviews vs Price" provides valuable insights into the relationship between the number of reviews and the price of different room types. Here are some observed patterns:
#
# 1. **Positive Correlation**: There appears to be a positive correlation between the number of reviews and price, particularly for 'Entire home/apt' and 'Private room' types. As the number of reviews increases, the price tends to rise as well.
#
# 2. **Room Type Distribution**: The three room types are represented by different colors. The majority of the data points are from 'Entire home/apt' (blue), followed by 'Private room' (orange) and a smaller number for 'Shared room' (green) and 'Hotel room' (red). This could suggest that 'Entire home/apt' listings are more prevalent in the dataset.
#
# ...

# %%
eda.plot_histogram(column='number_of_reviews', bins=20, title='Histogram of Number of Reviews')
# Out:
# ---
# ### LLM Analysis & Suggestion
# # Analysis
#
# The histogram of 'number_of_reviews' reveals a right-skewed distribution. Here are some key observations:
#
# 1. **Frequency Concentration**: A significant majority of entries (over 4,000) have a very low number of reviews, clustered around zero. This suggests that many items or entities have received few or no reviews.
#
# 2. **Long Tail**: As we move towards higher numbers of reviews, the frequency decreases sharply, indicating that only a small portion of items has a relatively high number of reviews (up to about 1,000). The long tail signifies that while most items are under-reviewed, a few are highly reviewed.
#
# 3. **Potential Outliers**: The presence of very few instances with reviews exceeding 600 could indicate outliers or exceptional cases that might warrant further investigation.
#
# ...
